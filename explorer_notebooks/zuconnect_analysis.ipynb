# %%
import eeg
test_bundles = eeg.extractBundledEEG("/Users/oreogundipe/Desktop/session_1/fusionDataExport_1698751111")
analysisEngine = eeg.analysisEngine({
    "eyes_closed": test_bundles.extractById(1698751111)
}, bundleType="ids")


analysisEngine.distributionVetting()

analysisEngine.basicComparisons()
# Out:
# eyes_closed {'delta': 0.9740147965752848, 'theta': 1.066170228301656, 'alpha': 0.9038363506731528, 'beta': 0.7848497280698591, 'gamma': 0.23246517817590334}

# %%
import eeg

session_2 = eeg.extractBundledEEG("/Users/oreogundipe/Desktop/session_2")
analysisEngine = eeg.analysisEngine({
    "eyes_closed": session_2.extractById(1698752213),
    "eyes_closed_music": session_2.extractById(1698752618)
}, bundleType="ids")


analysisEngine.distributionVetting()

analysisEngine.basicComparisons()
# Out:
# eyes_closed {'delta': 1.7788803408642573, 'theta': 1.8863662465884468, 'alpha': 1.3866649546153962, 'beta': 1.2097034508684312, 'gamma': 0.3263018890678088}
# eyes_closed_music {'delta': 1.1982582735276632, 'theta': 1.3038139784144411, 'alpha': 1.1792870621611782, 'beta': 0.9604812810472776, 'gamma': 0.2617724130771396}

# %%
import eeg

session_3 = eeg.extractBundledEEG("/Users/oreogundipe/Desktop/session_3")
analysisEngine = eeg.analysisEngine({
    "eyes_closed": session_3.extractById(1698753380),
    # "eyes_open_stroop_task": session_3.extractById(1698753926),
}, bundleType="ids", qualityCutoffFilter=.9)


analysisEngine.distributionVetting()

analysisEngine.basicComparisons()
# Out:
# eyes_closed {'delta': 2.474138326213318, 'theta': 2.2877740753370537, 'alpha': 1.364164336925657, 'beta': 1.004248853455885, 'gamma': 0.3157334325301113}

# %%
import eeg

session_4 = eeg.extractBundledEEG("/Users/oreogundipe/Desktop/session_4")
analysisEngine = eeg.analysisEngine({
    "eyes_closed": session_4.extractById(1698754301),
    "eyes_closed_music": session_4.extractById(1698754587),
}, bundleType="ids", qualityCutoffFilter=1)


analysisEngine.distributionVetting()

analysisEngine.basicComparisons()
# Out:
# eyes_closed {'delta': 1.3380438659926672, 'theta': 1.290373678447184, 'alpha': 0.8887371586578712, 'beta': 0.6008632011552223, 'gamma': 0.11727401575924543}
# eyes_closed_music {'delta': 1.2283886722349833, 'theta': 1.1602385112205555, 'alpha': 0.7721445759766933, 'beta': 0.5128981776927294, 'gamma': 0.10331733784096425}

# %%
import eeg

session_5 = eeg.extractBundledEEG("/Users/oreogundipe/Desktop/session_5")
analysisEngine = eeg.analysisEngine({
    "eyes_closed": session_5.extractById(1698755097),
    "eyes_open_flappy_bird": session_5.extractById(1698755367),
}, bundleType="ids", qualityCutoffFilter=1)


analysisEngine.distributionVetting()

analysisEngine.basicComparisons()
# Out:
# eyes_closed {'delta': 1.999333535270603, 'theta': 1.8104117615772592, 'alpha': 2.1230389432798273, 'beta': 0.7226794724389218, 'gamma': 0.11988169838230336}
# eyes_open_flappy_bird {'delta': 2.3619819942475613, 'theta': 2.0848210710010933, 'alpha': 1.703022468414302, 'beta': 1.6584539630552333, 'gamma': 0.25603503585363957}
